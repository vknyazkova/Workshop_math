# %%
from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %% [markdown]
# ### Установки и импорты

# %%
# !pip install pyyaml
# !pip install spacy-conll
# !python -m spacy download ru_core_news_sm
# !pip install pymorphy2
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.1)
# Requirement already satisfied: spacy-conll in /usr/local/lib/python3.10/dist-packages (3.4.0)
# Requirement already satisfied: spacy>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from spacy-conll) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (1.10.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.1->spacy-conll) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.1->spacy-conll) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.1->spacy-conll) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.1->spacy-conll) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.1->spacy-conll) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.1->spacy-conll) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.0.1->spacy-conll) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.0.1->spacy-conll) (0.1.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy>=3.0.1->spacy-conll) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=3.0.1->spacy-conll) (2.1.3)
# 2023-09-28 08:52:32.793438: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-28 08:52:34.075076: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting ru-core-news-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.6.0/ru_core_news_sm-3.6.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 64.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.6.0) (3.6.1)
# Requirement already satisfied: pymorphy3>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.6.0) (1.2.1)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.6.0) (0.7.2)
# Requirement already satisfied: docopt-ng>=0.6 in /usr/local/lib/python3.10/dist-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pymorphy3-dicts-ru in /usr/local/lib/python3.10/dist-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.6.0) (2.4.417150.4580142)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (1.10.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (0.1.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->ru-core-news-sm==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# Requirement already satisfied: pymorphy2 in /usr/local/lib/python3.10/dist-packages (0.9.1)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /usr/local/lib/python3.10/dist-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.10/dist-packages (from pymorphy2) (0.6.2)

# %%
from pathlib import Path
import importlib
import sys

import yaml
import spacy
from spacy_conll import init_parser
from spacy.language import Language

# %%
scripts_dir = Path('./project_scripts').resolve()
scripts_dir
# Out:
# PosixPath('/content/gdrive/MyDrive/project_scripts')

# %%
sys.path.append(str(scripts_dir))
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.10/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/gdrive/MyDrive/project_scripts']

# %%
from project_scripts.mathematicon_morph_parser import MorphologyCorrectionHandler, remove_double_spaces

# %%
importlib.reload(sys.modules['project_scripts.mathematicon_morph_parser'])
# Out:
# <module 'project_scripts.mathematicon_morph_parser' from '/content/gdrive/MyDrive/project_scripts/mathematicon_morph_parser.py'>

# %% [markdown]
# ### Работа с txt файлами

# %%
texts_folder = Path('./2_clean_texts').resolve()
conllu_folder = Path('./3_grammar_annotated').resolve()

# %%
def find_new_files(texts_folder, conllu_folder):
    conllu_files = [f.stem for f in conllu_folder.iterdir()]
    return [f for f in texts_folder.iterdir() if f.stem not in conllu_files]

# %%
new_files = find_new_files(texts_folder, conllu_folder)
new_files
# Out:
# [PosixPath('/content/gdrive/MyDrive/2_clean_texts/romanovvladimir_deleniiedrobei_5klass6klassmatematika_vsetemy.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/romanovvladimir_desiatichnayadrob_slozheniiedesyatychnyhdrobei_vychitaniyedesyatichnyhdrobei.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiky_robnyeracionalnyevyrazheniya_dejstviyasracionalnymidrobyami_algebra8klass_Urok13.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiky_kvadratniiyekorni_svoistvakvadratnyhkornei_algebra8klass_urok16.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/unknown_kvadratnyieurovneniya_razlozheniyekvadratnogotrehchlenanamnozhyteli_algebra8klass_urok19.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/romanovvladimir_kvadratniykoren_8klass_resheniyeprimerov.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/romanovvladimir_kvadratniykorenizdrobi_8klass_algebra.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/romanovvladimir_kvadratniykorenizproizvedenyia_8klass_algebra.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/unknown_kvadratniykorenizstepeni_8klass_algebra.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/znaikatv_matematika5klass_slozheniyeivychitaniyedesyatichnyhdrobei.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiky_mnogochleny_deistviyasmnogochlenami_algebra7klass_urok5.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiki_mnogochleny_deistviyasmnogochlenamy_algebra8klassurok6.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/matematika_natyralnyieitselyiechisla_ratschisla_irratschislaideistvchisla.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiki_deistviyasodnochlenamy__algebra7klass_urok4.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/romanovvladimir_osnovnoyesvoistvodrobi_5klass_6klass_urok1_matematika.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/izmatematikivalgebru_razlozheniyekvadratnogotriehchlenanamnozhytely.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/matematikaza5minut_ratsiirratschislaza5min.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiky_reshenyeprimerovpotemedrobniyeratsvyrash_algebra8klass_14.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiky_reshenyetipovyhzadaniypotemekvadratniyekorni_algebra8klass_urok17_videourokimatematiki.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/romanovvladimir_slozheniyedrobeisraznymiznamenateliamivychitaniyedrobei5i6klass.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiky_slozheniyeivychitanyedrobeisravnymiznamenatelyami_matematika56klassy_1o.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiky_slozheniyeivychitanyenatyralnyhchisel_matematika56klassy_2.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/izmatematikivalgebru_slozheniyemnogochlenov_algebra7klass.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/izmatematikivalgebru_slozheniyeodnochlenov_algebra7klass.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/romanovvladimir_slozheniyesmeshannyhchisel_vychitaniyesmeshannyhchisel5klass.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/romanovvladimir_sokrascheniyedrobei_5i6klassmatematika.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiky_sposobyrazlozheniyamnogochlenanamnozhiteli_algebra7klass_utok8.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiky_stepensnaturalnympokazatelem_svoistvastepeni_algebra7klass_urok3.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/unknown_stepenctselympokazatelem_primeryresheniyauprazhnenii_algebra8klass_15.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/romanovvladimir_umnozheniyedrobeisraznymiznamenateliami_56klass.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/unknown_umnozheniyeideleniyenaturalnyxchisel_matematika56klassi_3.txt'),
#  PosixPath('/content/gdrive/MyDrive/2_clean_texts/videourokimatematiky_formulisokraschennogoumnozheniya_algebra7klass_urok7.txt')]

# %%
from yaml.parser import ParserError

# %%
files_info = {}
for f in new_files:
    with open(f, encoding='utf-8') as fh:
        try:
            read_data = yaml.load(fh, Loader=yaml.FullLoader)
            read_data['text'] = remove_double_spaces(read_data['text'])
            files_info[f] = read_data
        except ParserError as e:
            print(e)
            print()
            print(f'Some problems with file {f}')
        finally:
            continue

# %% [markdown]
# ### Парсинг

# %%
@Language.factory(
    "morphology_corrector",
    assigns=["token.lemma", "token.tag"],
    requires=["token.pos"],
    default_config={"mode": 'allpos+ptcp+conv'},
)
def morphology_corrector(nlp, name, mode):
    return MorphologyCorrectionHandler(mode)

# %%
nlp = init_parser("ru_core_news_sm", 'spacy', include_headers=True, exclude_spacy_components=['ner'])
nlp.add_pipe('morphology_corrector', before="conll_formatter")

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x79ad46465780>),
#  ('morphologizer',
#   <spacy.pipeline.morphologizer.Morphologizer at 0x79ad46465ba0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x79ad466e2110>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x79ad4671d700>),
#  ('lemmatizer',
#   <spacy.lang.ru.lemmatizer.RussianLemmatizer at 0x79ad464e1ac0>),
#  ('morphology_corrector',
#   <project_scripts.mathematicon_morph_parser.MorphologyCorrectionHandler at 0x79ad3dd3c5e0>),
#  ('conll_formatter',
#   ConllFormatter(conversion_maps=None, ext_names={'conll_str': 'conll_str', 'conll': 'conll', 'conll_pd': 'conll_pd'}, field_names={'ID': 'ID', 'FORM': 'FORM', 'LEMMA': 'LEMMA', 'UPOS': 'UPOS', 'XPOS': 'XPOS', 'FEATS': 'FEATS', 'HEAD': 'HEAD', 'DEPREL': 'DEPREL', 'DEPS': 'DEPS', 'MISC': 'MISC'}, include_headers=True, disable_pandas=False))]

# %%
def write_conllu(doc, source_filename, dest_dir):
    result_path = Path(dest_dir, source_filename.with_suffix('.conllu').name)
    with open(result_path, 'w', encoding='utf-8') as f:
        f.write(doc._.conll_str)
    return result_path

# %%
written_files = []
for filename, info in files_info.items():
    parsed_text = nlp(info['text'])
    written_files.append(write_conllu(parsed_text, filename, conllu_folder))
written_files
# Out:
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# Exception "'NoneType' object has no attribute 'word'" was raised on token (бэ, VERB, бэ) during execution of "ptcp_corrector" function
# [PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/romanovvladimir_deleniiedrobei_5klass6klassmatematika_vsetemy.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/romanovvladimir_desiatichnayadrob_slozheniiedesyatychnyhdrobei_vychitaniyedesyatichnyhdrobei.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiky_robnyeracionalnyevyrazheniya_dejstviyasracionalnymidrobyami_algebra8klass_Urok13.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiky_kvadratniiyekorni_svoistvakvadratnyhkornei_algebra8klass_urok16.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/unknown_kvadratnyieurovneniya_razlozheniyekvadratnogotrehchlenanamnozhyteli_algebra8klass_urok19.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/romanovvladimir_kvadratniykoren_8klass_resheniyeprimerov.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/romanovvladimir_kvadratniykorenizdrobi_8klass_algebra.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/romanovvladimir_kvadratniykorenizproizvedenyia_8klass_algebra.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/unknown_kvadratniykorenizstepeni_8klass_algebra.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/znaikatv_matematika5klass_slozheniyeivychitaniyedesyatichnyhdrobei.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiky_mnogochleny_deistviyasmnogochlenami_algebra7klass_urok5.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiki_mnogochleny_deistviyasmnogochlenamy_algebra8klassurok6.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/matematika_natyralnyieitselyiechisla_ratschisla_irratschislaideistvchisla.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiki_deistviyasodnochlenamy__algebra7klass_urok4.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/romanovvladimir_osnovnoyesvoistvodrobi_5klass_6klass_urok1_matematika.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/izmatematikivalgebru_razlozheniyekvadratnogotriehchlenanamnozhytely.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/matematikaza5minut_ratsiirratschislaza5min.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiky_reshenyeprimerovpotemedrobniyeratsvyrash_algebra8klass_14.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiky_reshenyetipovyhzadaniypotemekvadratniyekorni_algebra8klass_urok17_videourokimatematiki.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/romanovvladimir_slozheniyedrobeisraznymiznamenateliamivychitaniyedrobei5i6klass.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiky_slozheniyeivychitanyedrobeisravnymiznamenatelyami_matematika56klassy_1o.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiky_slozheniyeivychitanyenatyralnyhchisel_matematika56klassy_2.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/izmatematikivalgebru_slozheniyemnogochlenov_algebra7klass.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/izmatematikivalgebru_slozheniyeodnochlenov_algebra7klass.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/romanovvladimir_slozheniyesmeshannyhchisel_vychitaniyesmeshannyhchisel5klass.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/romanovvladimir_sokrascheniyedrobei_5i6klassmatematika.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiky_sposobyrazlozheniyamnogochlenanamnozhiteli_algebra7klass_utok8.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiky_stepensnaturalnympokazatelem_svoistvastepeni_algebra7klass_urok3.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/unknown_stepenctselympokazatelem_primeryresheniyauprazhnenii_algebra8klass_15.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/romanovvladimir_umnozheniyedrobeisraznymiznamenateliami_56klass.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/unknown_umnozheniyeideleniyenaturalnyxchisel_matematika56klassi_3.conllu'),
#  PosixPath('/content/gdrive/MyDrive/3_grammar_annotated/videourokimatematiky_formulisokraschennogoumnozheniya_algebra7klass_urok7.conllu')]
